# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 450          451         0       2
# 451          452         0       3
# 452          453         0       1
# 453          454         1       1
# 454          455         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
air_quality = pd.read_csv("air_quality_long.csv", index_col="date.utc", parse_dates=True)
air_quality
# Out:
#                                 city country            location parameter  \
# date.utc
# 2019-06-18 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 08:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 07:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 06:00:00+00:00  Antwerpen      BE             BETR801      pm25
# 2019-06-17 05:00:00+00:00  Antwerpen      BE             BETR801      pm25
# ...                              ...     ...                 ...       ...
# 2019-06-17 01:00:00+00:00     London      GB  London Westminster      pm25
# 2019-06-17 00:00:00+00:00     London      GB  London Westminster      pm25
# 2019-06-16 23:00:00+00:00     London      GB  London Westminster      pm25
# 2019-06-16 21:00:00+00:00     London      GB  London Westminster      pm25
# 2019-06-16 20:00:00+00:00     London      GB  London Westminster      pm25
#
#                            value   unit
# date.utc
# ...

# %% [markdown]
# # Ordenar la data de titanic por edad y Pclass

# %%
titanic.sort_values(by='Age')
# Out:
#      PassengerId  Survived  Pclass  \
# 78            79         1       2
# 305          306         1       1
# 183          184         1       2
# 381          382         1       3
# 164          165         0       3
# ..           ...       ...     ...
# 428          429         0       3
# 431          432         1       3
# 444          445         1       3
# 451          452         0       3
# 454          455         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 78                       Caldwell, Master. Alden Gates    male  0.83      0
# 305                     Allison, Master. Hudson Trevor    male  0.92      1
# 183                          Becker, Master. Richard F    male  1.00      2
# 381                        Nakid, Miss. Maria ("Mary")  female  1.00      0
# 164                       Panula, Master. Eino Viljami    male  1.00      4
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic.sort_values(by=['Pclass', 'Age'], ascending=True).head()
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 305          306         1       1  Allison, Master. Hudson Trevor    male
# 297          298         0       1    Allison, Miss. Helen Loraine  female
# 445          446         1       1       Dodge, Master. Washington    male
# 435          436         1       1       Carter, Miss. Lucile Polk  female
# 329          330         1       1    Hippach, Miss. Jean Gertrude  female
#
#        Age  SibSp  Parch  Ticket      Fare    Cabin Embarked
# 305   0.92      1      2  113781  151.5500  C22 C26        S
# 297   2.00      1      2  113781  151.5500  C22 C26        S
# 445   4.00      0      2   33638   81.8583      A34        S
# 435  14.00      1      2  113760  120.0000  B96 B98        S
# 329  16.00      0      1  111361   57.9792      B18        C

# %%
####### https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/07_reshape_table_layout.html

# %%
#Long to wide table format
