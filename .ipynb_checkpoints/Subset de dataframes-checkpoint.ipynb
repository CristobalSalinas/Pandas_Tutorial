# %%
import pandas as pd

# %%
titanic = pd.read_csv("titanic.csv")
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 450          451         0       2
# 451          452         0       3
# 452          453         0       1
# 453          454         1       1
# 454          455         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
ages = titanic['Age']
ages
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 450    36.0
# 451     NaN
# 452    30.0
# 453    49.0
# 454     NaN
# Name: Age, Length: 455, dtype: float64

# %%
print(titanic.shape)
print(ages.shape)
# Out:
# (455, 12)
# (455,)

# %%
print(type(ages))
print(type(titanic))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Puedo seleccionar un dataframe de un dataframe

# %%
test = titanic[['Age','Sex']]
test
# Out:
#       Age     Sex
# 0    22.0    male
# 1    38.0  female
# 2    26.0  female
# 3    35.0  female
# 4    35.0    male
# ..    ...     ...
# 450  36.0    male
# 451   NaN    male
# 452  30.0    male
# 453  49.0    male
# 454   NaN    male
#
# [455 rows x 2 columns]

# %%
print(test.shape)
# Out:
# (455, 2)

# %% [markdown]
# ### Filtrar dataframe por valor especifico

# %%
arriba_35 = titanic[titanic['Age'] > 35]

arriba_35
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 438          439         0       1
# 440          441         1       2
# 449          450         1       1
# 450          451         0       2
# 453          454         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                     Hewlett, Mrs. (Mary D Kingcome)  female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
arriba_35.shape
# Out:
# (101, 12)

# %% [markdown]
# ### alguna condicion especifica

# %%
class_23 = titanic[titanic['Pclass'].isin([2,3])]
class_23
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 0              1         0       3            Braund, Mr. Owen Harris    male
# 2              3         1       3             Heikkinen, Miss. Laina  female
# 4              5         0       3           Allen, Mr. William Henry    male
# 5              6         0       3                   Moran, Mr. James    male
# 7              8         0       3     Palsson, Master. Gosta Leonard    male
# ..           ...       ...     ...                                ...     ...
# 446          447         1       2  Mellinger, Miss. Madeleine Violet  female
# 448          449         1       3     Baclini, Miss. Marie Catherine  female
# 450          451         0       2              West, Mr. Edwy Arthur    male
# 451          452         0       3    Hagland, Mr. Ingvald Olai Olsen    male
# 454          455         0       3                Peduzzi, Mr. Joseph    male
#
# ...

# %%
class_23 = titanic[(titanic['Pclass'] == 2) | (titanic['Pclass'] == 3)]
class_23
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 0              1         0       3            Braund, Mr. Owen Harris    male
# 2              3         1       3             Heikkinen, Miss. Laina  female
# 4              5         0       3           Allen, Mr. William Henry    male
# 5              6         0       3                   Moran, Mr. James    male
# 7              8         0       3     Palsson, Master. Gosta Leonard    male
# ..           ...       ...     ...                                ...     ...
# 446          447         1       2  Mellinger, Miss. Madeleine Violet  female
# 448          449         1       3     Baclini, Miss. Marie Catherine  female
# 450          451         0       2              West, Mr. Edwy Arthur    male
# 451          452         0       3    Hagland, Mr. Ingvald Olai Olsen    male
# 454          455         0       3                Peduzzi, Mr. Joseph    male
#
# ...

# %% [markdown]
# ### Ver pasajeros los cuales su edad si exista

# %%
age_no_na = titanic[titanic['Age'].notna()]
age_no_na
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 448          449         1       3
# 449          450         1       1
# 450          451         0       2
# 452          453         0       1
# 453          454         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Seleccionar rows y columnas especificas

# %%
# Quiero obtener los nombres de los pasajeros mas viejos que 35
olders = titanic.loc[titanic['Age']>35,['Name','Sex']]
olders
# Out:
#                                                   Name     Sex
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 6                              McCarthy, Mr. Timothy J    male
# 11                            Bonnell, Miss. Elizabeth  female
# 13                         Andersson, Mr. Anders Johan    male
# 15                     Hewlett, Mrs. (Mary D Kingcome)  female
# ..                                                 ...     ...
# 438                                  Fortune, Mr. Mark    male
# 440        Hart, Mrs. Benjamin (Esther Ada Bloomfield)  female
# 449                     Peuchen, Major. Arthur Godfrey    male
# 450                              West, Mr. Edwy Arthur    male
# 453                           Goldenberg, Mr. Samuel L    male
#
# [101 rows x 2 columns]

# %% [markdown]
# ### Obteniendo rows desde el 10 hasta el 25 y columnas desde el 3 al 5

# %%
# Imprimiendo primero como se ve normalmente
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 450          451         0       2
# 451          452         0       3
# 452          453         0       1
# 453          454         1       1
# 454          455         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# ahora como queremos
titanic.iloc[9:25,2:5]
# Out:
#     Pclass                                               Name     Sex
# 9        2                Nasser, Mrs. Nicholas (Adele Achem)  female
# 10       3                    Sandstrom, Miss. Marguerite Rut  female
# 11       1                           Bonnell, Miss. Elizabeth  female
# 12       3                     Saundercock, Mr. William Henry    male
# 13       3                        Andersson, Mr. Anders Johan    male
# 14       3               Vestrom, Miss. Hulda Amanda Adolfina  female
# 15       2                    Hewlett, Mrs. (Mary D Kingcome)  female
# 16       3                               Rice, Master. Eugene    male
# 17       2                       Williams, Mr. Charles Eugene    male
# 18       3  Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 19       3                            Masselmani, Mrs. Fatima  female
# 20       2                               Fynney, Mr. Joseph J    male
# ...

# %%
titanic.iloc[0:3,3] = "Anonimo"
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                                       Anonimo    male  22.0      1      0
# 1                                       Anonimo  female  38.0      1      0
# 2                                       Anonimo  female  26.0      0      0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#              Ticket       Fare Cabin Embarked
# 0         A/5 21171     7.2500   NaN        S
# 1          PC 17599    71.2833   C85        C
# 2  STON/O2. 3101282  7925.0000   NaN        S
# 3            113803    53.1000  C123        S
# 4            373450     8.0500   NaN        S

# %% [markdown]
# ### Entonces para recordar
# #### * Para seleccionar data dentro del dataframe lo hacemos con []
# #### * dentro de estas podemos usar un simple nombre de columna o row, una lista, condiciones etc
# #### * loc para obtener las rows y columas
# #### * iloc para posiciones de las tablas
# #### * de iloc/loc podemos asignarles nuevos valores
